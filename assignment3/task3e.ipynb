# %% [markdown]
# This is a simple example on how you can use a jupyter notebook to train your model :)

# %%
import torch
import torch.nn as nn
from dataloaders import load_cifar10
from trainer import Trainer, compute_loss_and_accuracy
from task2 import create_plots

# %%
class ModelBest(nn.Module):

    def __init__(self,
                 image_channels,
                 num_classes):
        """
            Is called when model is initialized.
            Args:
                image_channels. Number of color channels in image (3)
                num_classes: Number of classes we want to predict (10)
        """
        super().__init__()

        P = 1
        K = 3
        S = 1
        
        self.num_classes = num_classes
        self.feature_extractor = nn.Sequential( 
            #clayer1
            nn.Conv2d(in_channels = 3, out_channels = 32, kernel_size = K, stride = S, padding = P),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size = 2,stride = 2),
            nn.Dropout(p = 0.2),
            #clayer2
            nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = 5, stride = S, padding = 2),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size = 2, stride = 2),
            nn.Dropout(p=0.2),
            #clayer3
            nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = K, stride = S, padding = P),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size = 2, stride = 2),
            nn.Dropout(p = 0.2),
            #clayer4
            nn.Conv2d(in_channels = 128, out_channels = 128, kernel_size = K, stride = S, padding = P),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(kernel_size = 2, stride = 2),
            nn.Dropout(p = 0.2),
        )

        # The output of feature_extractor will be [batch_size, num_filters, 16, 16]
        self.num_output_features = 128*4 #32*32*32
        # Initialize our last fully connected layer
        # Inputs all extracted features from the convolutional layers
        # Outputs num_classes predictions, 1 for each class.
        # There is no need for softmax activation function, as this is
        # included with nn.CrossEntropyLoss
        
        self.classifier = nn.Sequential(
            nn.Linear(self.num_output_features, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            #nn.Dropout(p = 0.1),
            nn.Linear(64, 32),
            nn.ReLU(),
            #nn.Dropout(p = 0.2),
            nn.Linear(32, 10),
        )

    def forward(self, x):
        """
        Performs a forward pass through the model
        Args:
            x: Input image, shape: [batch_size, 3, 32, 32]
        """
        # TODO: Implement this function (Task  2a)
        batch_size = x.shape[0]
        out = x
        expected_shape = (batch_size, self.num_classes)
        
        clayer = self.feature_extractor(out)
        clayer = clayer.view(batch_size, -1)
        out = self.classifier(clayer)   
        
        assert out.shape == (batch_size, self.num_classes),\
            f"Expected output of forward pass to be: {expected_shape}, but got: {out.shape}"
        return out

# %%
epochs = 10
batch_size = 64
learning_rate = 10e-2 # Should be 5e-5 for LeNet
early_stop_count = 4
dataloaders = load_cifar10(batch_size)
model = ModelBest(image_channels = 4, num_classes = 10)
trainer = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model,
    dataloaders
)
trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ModelBest(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (6): ReLU()
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): Dropout(p=0.2, inplace=False)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): Dropout(p=0.2, inplace=False)
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=64, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
# Epoch: 0, Batches per seconds: 33.56, Global step:    351, Validation Loss: 1.39, Validation Accuracy: 0.501
# Epoch: 0, Batches per seconds: 34.52, Global step:    702, Validation Loss: 1.07, Validation Accuracy: 0.617
# Epoch: 1, Batches per seconds: 35.24, Global step:   1053, Validation Loss: 1.08, Validation Accuracy: 0.622
# Epoch: 1, Batches per seconds: 35.76, Global step:   1404, Validation Loss: 0.92, Validation Accuracy: 0.683
# Epoch: 2, Batches per seconds: 36.04, Global step:   1755, Validation Loss: 0.82, Validation Accuracy: 0.712
# Epoch: 2, Batches per seconds: 36.28, Global step:   2106, Validation Loss: 0.90, Validation Accuracy: 0.685
# Epoch: 3, Batches per seconds: 36.38, Global step:   2457, Validation Loss: 0.86, Validation Accuracy: 0.710
# Epoch: 3, Batches per seconds: 36.36, Global step:   2808, Validation Loss: 0.77, Validation Accuracy: 0.735
# Epoch: 4, Batches per seconds: 36.32, Global step:   3159, Validation Loss: 0.83, Validation Accuracy: 0.726
# Epoch: 4, Batches per seconds: 36.33, Global step:   3510, Validation Loss: 0.72, Validation Accuracy: 0.756
# Epoch: 5, Batches per seconds: 36.36, Global step:   3861, Validation Loss: 0.76, Validation Accuracy: 0.745
# Epoch: 5, Batches per seconds: 36.41, Global step:   4212, Validation Loss: 0.73, Validation Accuracy: 0.757
# Epoch: 6, Batches per seconds: 36.39, Global step:   4563, Validation Loss: 0.70, Validation Accuracy: 0.763
# Epoch: 6, Batches per seconds: 36.41, Global step:   4914, Validation Loss: 0.69, Validation Accuracy: 0.768
# Epoch: 7, Batches per seconds: 36.40, Global step:   5265, Validation Loss: 0.79, Validation Accuracy: 0.745
# Epoch: 7, Batches per seconds: 36.47, Global step:   5616, Validation Loss: 0.71, Validation Accuracy: 0.764
# Epoch: 8, Batches per seconds: 36.46, Global step:   5967, Validation Loss: 0.73, Validation Accuracy: 0.766
# Early stop criteria met
# Early stopping.

# %%
#Calculate train, test and validation accuracy
model.eval()
test = trainer.dataloader_test
train = trainer.dataloader_train
val = trainer.dataloader_val
print(compute_loss_and_accuracy(val, model = model, loss_criterion = nn.CrossEntropyLoss()))
print(compute_loss_and_accuracy(test, model = model, loss_criterion = nn.CrossEntropyLoss()))
print(compute_loss_and_accuracy(train, model = model, loss_criterion = nn.CrossEntropyLoss()))
# Out:
# (tensor(0.7319, device='cuda:0'), 0.7656)
# (tensor(0.7347, device='cuda:0'), 0.7618)
# (tensor(0.4234, device='cuda:0'), 0.8537517780938834)

# %%
create_plots(trainer, "overwrite")
